# %% [markdown]
# # Test the hypothesis that the delay is from Normal distribution. and that mean of the delay is 0.

# %% [markdown]
# * This task is asking for 2 hypothesis tests:
# 1. A Normality test for normal distribution
# 2. A Ttest to compare the sample mean with a mean of 0.
#
#
# This is also an opportunity to do some EDA and explore the flights.csv dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
## read the big flights_csv file in chunks of 1 million rows at a time
chunk = pd.read_csv('../Modeling/datasets/flights.csv', chunksize=1000000, low_memory=False)
df = pd.concat(chunk)

# %% [markdown]
# **Research** 'tail_num' is a unique aircraft vehicle identifier (like a VIM for motor vehicles),
# and might be an important feature. Ensure that will cleaning outliers, we do not lose data on this.

# %%
# take only the relevant columns and remove Null values
delay_dist = df[['arr_delay', 'tail_num', 'crs_arr_time', 'arr_time']]
delay_dist.info()
tail_numbers = delay_dist['tail_num'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15927485 entries, 0 to 15927484
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   arr_delay     float64
#  1   tail_num      object
#  2   crs_arr_time  int64
#  3   arr_time      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 486.1+ MB

# %% [markdown]
# **cleaning the dataset** - check for null values of arr_delay and confirm that they're actually missing, and not incorrecltly assigned 0s by checking of `arr_time` (actual arrival time) is the same as `crs_arr_time` the scheduled arrival time.

# %%
# filter and repeat the count
filter1 = delay_dist['arr_delay'].isna() # missing delay
filter2 = delay_dist['crs_arr_time'] == delay_dist['arr_time'] 
len(delay_dist[(filter1) & (filter2)])


# loop through all those records and set arr_delay to 0
indices = delay_dist[(filter1) & (filter2)].index.to_list()

for idx in indices:
    delay_dist.loc[idx, 'arr_delay'] = 0



# remove the extra columns and Null values of arr_delay

delay_dist.dropna(inplace=True)
delay_dist.drop(columns=['arr_time', 'crs_arr_time'])
# Out:
#           arr_delay tail_num
# 0             -42.0   N633NK
# 1              -1.0   N684NK
# 2              -1.0   N640NK
# 3             -14.0   N510NK
# 4              11.0   N617NK
# ...             ...      ...
# 15927480      -16.0   N535NK
# 15927481       -4.0   N605NK
# 15927482      -11.0   N667NK
# 15927483      -19.0   N535NK
# 15927484      -13.0   N535NK
#
# [15618331 rows x 2 columns]

# %%
delay_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15618331 entries, 0 to 15927484
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   arr_delay     float64
#  1   tail_num      object
#  2   crs_arr_time  int64
#  3   arr_time      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 595.8+ MB

# %%
# visualize the distribution 
plt.hist(delay_dist['arr_delay'], bins=100)
plt.title('Distribution of Arrival_delay\n before trimming outliers')
plt.xlabel('arr_delay')
plt.show()

sns.boxplot(delay_dist['arr_delay'])
plt.yticks(np.arange(-1200,3200,step=200))
plt.grid(which='both')
plt.title('Box plot of Arrival delay \nbefore trimming outliers')

plt.show()

# %% [markdown]
# ## Removing outliers
#
# As noted above, we will delete outliers as much as possible and still preserve `tail_num` information.

# %%
filter1 = delay_dist['arr_delay'] > 1000 
filter2 = delay_dist['arr_delay'] < -200
filter = (filter1)| (filter2)
outliers = delay_dist[filter]

remainders = delay_dist[~filter]
remainder_tail_nums = remainders['tail_num'].unique()
df_clean = df.loc[remainders.index].copy()
delay_dist_clean = delay_dist.loc[remainders.index].copy()

# %%
delay_dist_clean = delay_dist.loc[remainders.index].copy()
delay = delay_dist_clean['arr_delay'].dropna()

# %%
# further visualizations before running the normality tests...
sns.boxplot(delay)
plt.yticks(np.arange(-300,1200,step=200))
plt.grid(which='both')
plt.title('Distribution of Arrival_delay after trimming outliers')
plt.xlabel('arr_delay')
plt.show()
plt.hist(delay)
plt.title('Box plot of Arrival delay after trimming outliers')
plt.show()

# %%
## Testing

# %%
## Running the Normality test with shapiro

from scipy.stats import shapiro

stat, p = shapiro(delay.values)

print(f'p is {p}')
print('The distribution is', 
      'not Gaussian.' if p < 0.05 else 'probably Gaussian.')
# Out:
# p is 0.0
# The distribution is not Gaussian.

# %%
## Running the Ttest and comparing to a mean of 0


from scipy.stats import ttest_1samp
stats, p = ttest_1samp(delay.values, popmean=0)

print(f'p is {p}')
print('The mean of the distribution is', 
      (' not' if p < 0.05 else ' probably'),
     'equal to 0.')
# Out:
# p is 0.0
# The mean of the distribution is  not equal to 0.

# %% [markdown]
# ## Summary
#
# 1. Test for Hypothesis that the distribution is a normal distribution.
# - **Result**: The distribution is probably not a normal distribution.
#
#
#
# 2. Testing the Hypothesis that the distribution has a mean of zero.
# - **Result**: The distribution probably does not have a mean of zero.
