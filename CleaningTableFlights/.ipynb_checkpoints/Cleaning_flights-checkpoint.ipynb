# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read the flights
df = pd.read_csv('data/flights.csv')
df.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-05-31                 WN                 WN          WN
# 1  2019-04-20                 AA                 AA          AA
# 2  2019-02-13                 WN                 WN          WN
# 3  2018-11-20                 AA                 AA          AA
# 4  2018-08-28                 DL       DL_CODESHARE          DL
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                2081                WN   N402WN               2081
# 1                2244                AA   N895NN               2244
# 2                1731                WN   N8507C               1731
# 3                2620                AA   N961AN               2620
# 4                4060                9E   N833AY               4060
#
#    origin_airport_id origin  ... distance  carrier_delay weather_delay  \
# 0              10800    BUR  ...      326            0.0           0.0
# ...

# %%
# data sctructure
df.describe()
# Out:
#        mkt_carrier_fl_num  op_carrier_fl_num  origin_airport_id  \
# count       200000.000000      200000.000000      200000.000000
# mean          2735.501405        2735.466465       12681.792960
# std           1864.137816        1864.243219        1524.816624
# min              1.000000           1.000000       10135.000000
# 25%           1123.000000        1123.000000       11292.000000
# 50%           2318.000000        2318.000000       12889.000000
# 75%           4332.000000        4332.000000       14057.000000
# max           9390.000000        9390.000000       16869.000000
#
#        dest_airport_id   crs_dep_time       dep_time      dep_delay  \
# count    200000.000000  200000.000000  196767.000000  196717.000000
# mean      12681.283465    1329.486130    1334.249752      10.669785
# std        1523.072185     489.735055     503.468605      49.146377
# min       10135.000000       1.000000       1.000000     -41.000000
# ...

# %%
#Looking at columns and null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 42 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   fl_date              200000 non-null  object
#  1   mkt_unique_carrier   200000 non-null  object
#  2   branded_code_share   200000 non-null  object
#  3   mkt_carrier          200000 non-null  object
#  4   mkt_carrier_fl_num   200000 non-null  int64
#  5   op_unique_carrier    200000 non-null  object
#  6   tail_num             199399 non-null  object
#  7   op_carrier_fl_num    200000 non-null  int64
#  8   origin_airport_id    200000 non-null  int64
#  9   origin               200000 non-null  object
#  10  origin_city_name     200000 non-null  object
#  11  dest_airport_id      200000 non-null  int64
#  12  dest                 200000 non-null  object
#  13  dest_city_name       200000 non-null  object
#  14  crs_dep_time         200000 non-null  int64
# ...

# %%
# check for null values
df.isnull().sum()
# Out:
# fl_date                     0
# mkt_unique_carrier          0
# branded_code_share          0
# mkt_carrier                 0
# mkt_carrier_fl_num          0
# op_unique_carrier           0
# tail_num                  601
# op_carrier_fl_num           0
# origin_airport_id           0
# origin                      0
# origin_city_name            0
# dest_airport_id             0
# dest                        0
# dest_city_name              0
# crs_dep_time                0
# dep_time                 3233
# dep_delay                3283
# taxi_out                 3424
# wheels_off               3424
# wheels_on                3504
# taxi_in                  3504
# crs_arr_time                0
# arr_time                 3422
# arr_delay                3840
# cancelled                   0
# cancellation_code      196633
# diverted                    0
# dup                         0
# crs_elapsed_time            0
# actual_elapsed_time      3807
# air_time                 3889
# ...

# %%
# missing values percent in columns
def missing_values_table(df):
        '''function that checks dataframe for missing values and returns a table with the results'''
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        print(mis_val_table_ren_columns)

# %%
missing_values_table (df)
# Out:
#                            Missing Values  % of Total Values
# fl_date                                 0             0.0000
# mkt_unique_carrier                      0             0.0000
# branded_code_share                      0             0.0000
# mkt_carrier                             0             0.0000
# mkt_carrier_fl_num                      0             0.0000
# op_unique_carrier                       0             0.0000
# tail_num                              601             0.3005
# op_carrier_fl_num                       0             0.0000
# origin_airport_id                       0             0.0000
# origin                                  0             0.0000
# origin_city_name                        0             0.0000
# dest_airport_id                         0             0.0000
# dest                                    0             0.0000
# dest_city_name                          0             0.0000
# ...

# %%
to_drop = ['tail_num',
          'taxi_out',
          'wheels_off',
          'wheels_on',
          'taxi_in',
          'flights',
          'actual_elapsed_time',  
          'air_time',
          'first_dep_time',
          'total_add_gtime',
          'longest_add_gtime',
          'no_name']

# %%
df = df.drop(to_drop, axis=1)
df.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-05-31                 WN                 WN          WN
# 1  2019-04-20                 AA                 AA          AA
# 2  2019-02-13                 WN                 WN          WN
# 3  2018-11-20                 AA                 AA          AA
# 4  2018-08-28                 DL       DL_CODESHARE          DL
#
#    mkt_carrier_fl_num op_unique_carrier  op_carrier_fl_num  origin_airport_id  \
# 0                2081                WN               2081              10800
# 1                2244                AA               2244              13930
# 2                1731                WN               1731              13495
# 3                2620                AA               2620              11298
# 4                4060                9E               4060              12478
#
#   origin       origin_city_name  ...  diverted dup crs_elapsed_time  distance  \
# ...

# %%
missing_values_table (df)
# Out:
#                            Missing Values  % of Total Values
# fl_date                                 0             0.0000
# mkt_unique_carrier                      0             0.0000
# branded_code_share                      0             0.0000
# mkt_carrier                             0             0.0000
# mkt_carrier_fl_num                      0             0.0000
# op_unique_carrier                       0             0.0000
# op_carrier_fl_num                       0             0.0000
# origin_airport_id                       0             0.0000
# origin                                  0             0.0000
# origin_city_name                        0             0.0000
# dest_airport_id                         0             0.0000
# dest                                    0             0.0000
# dest_city_name                          0             0.0000
# crs_dep_time                            0             0.0000
# ...

# %%
#for null value of cancellation_code replace with NC - not cancelled
df['cancellation_code'] = df['cancellation_code'].replace(np.nan, 'NC')
print(df.cancellation_code.isnull().sum())
# Out:
# 0

# %%
missing_values_table (df)
# Out:
#                            Missing Values  % of Total Values
# fl_date                                 0             0.0000
# mkt_unique_carrier                      0             0.0000
# branded_code_share                      0             0.0000
# mkt_carrier                             0             0.0000
# mkt_carrier_fl_num                      0             0.0000
# op_unique_carrier                       0             0.0000
# op_carrier_fl_num                       0             0.0000
# origin_airport_id                       0             0.0000
# origin                                  0             0.0000
# origin_city_name                        0             0.0000
# dest_airport_id                         0             0.0000
# dest                                    0             0.0000
# dest_city_name                          0             0.0000
# crs_dep_time                            0             0.0000
# ...

# %%
df['carrier_delay'] = df['carrier_delay'].replace(np.nan, 0)
print(df.carrier_delay.isnull().sum())
# Out:
# 0

# %%
df['weather_delay'] = df['weather_delay'].replace(np.nan, 0)
print(df.weather_delay.isnull().sum())
# Out:
# 0

# %%
df['nas_delay'] = df['nas_delay'].replace(np.nan, 0)
print(df.nas_delay.isnull().sum())
# Out:
# 0

# %%
df['security_delay'] = df['security_delay'].replace(np.nan, 0)
print(df.security_delay.isnull().sum())
# Out:
# 0

# %%
df['late_aircraft_delay'] = df['late_aircraft_delay'].replace(np.nan, 0)
print(df.late_aircraft_delay.isnull().sum())
# Out:
# 0

# %%
missing_values_table (df)
# Out:
#                            Missing Values  % of Total Values
# fl_date                                 0             0.0000
# mkt_unique_carrier                      0             0.0000
# branded_code_share                      0             0.0000
# mkt_carrier                             0             0.0000
# mkt_carrier_fl_num                      0             0.0000
# op_unique_carrier                       0             0.0000
# op_carrier_fl_num                       0             0.0000
# origin_airport_id                       0             0.0000
# origin                                  0             0.0000
# origin_city_name                        0             0.0000
# dest_airport_id                         0             0.0000
# dest                                    0             0.0000
# dest_city_name                          0             0.0000
# crs_dep_time                            0             0.0000
# ...

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# check for duplicate customer id's using len() and print the number of duplicates
print(len(df['mkt_carrier_fl_num']) - len(df['mkt_carrier_fl_num'].unique()))
# Out:
# 193143

# %%
df['unique_mkt_carrier_fl_num'] = df['mkt_carrier'] + df['mkt_carrier_fl_num'].astype(str)

df.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-05-31                 WN                 WN          WN
# 1  2019-04-20                 AA                 AA          AA
# 2  2019-02-13                 WN                 WN          WN
# 3  2018-11-20                 AA                 AA          AA
# 4  2018-08-28                 DL       DL_CODESHARE          DL
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                2081                WN   N402WN               2081
# 1                2244                AA   N895NN               2244
# 2                1731                WN   N8507C               1731
# 3                2620                AA   N961AN               2620
# 4                4060                9E   N833AY               4060
#
#    origin_airport_id origin  ... carrier_delay  weather_delay nas_delay  \
# 0              10800    BUR  ...           0.0            0.0      51.0
# ...

# %%
# check for duplicate customer id's using len() and print the number of duplicates
print(len(df['unique_mkt_carrier_fl_num']) - len(df['unique_mkt_carrier_fl_num'].unique()))
# Out:
# 170335
